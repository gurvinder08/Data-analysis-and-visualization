# %%
import pandas as pd

# %%
df=pd.read_csv("IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.size
# Out:
# 750

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df.describe() #statistical features
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isna().any().any()
# Out:
# False

# %%
df.head(100)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 0            5.1          3.5           1.4          0.2      Iris-setosa
# 1            4.9          3.0           1.4          0.2      Iris-setosa
# 2            4.7          3.2           1.3          0.2      Iris-setosa
# 3            4.6          3.1           1.5          0.2      Iris-setosa
# 4            5.0          3.6           1.4          0.2      Iris-setosa
# ..           ...          ...           ...          ...              ...
# 95           5.7          3.0           4.2          1.2  Iris-versicolor
# 96           5.7          2.9           4.2          1.3  Iris-versicolor
# 97           6.2          2.9           4.3          1.3  Iris-versicolor
# 98           5.1          2.5           3.0          1.1  Iris-versicolor
# 99           5.7          2.8           4.1          1.3  Iris-versicolor
#
# [100 rows x 5 columns]

# %%
#to see all the rows and columns
with pd.option_context("display.min_rows",20,"display.max_rows",100,"display.max_columns",5,"display.max_colwidth",50):
    display(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# ...

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)
pd.set_option('display.max_colwidth',None)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# ...

# %%
df.iloc[0:10,0:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
import matplotlib.pyplot as plt

# %%
fig, axis = plt.subplots()
axis.scatter(df['sepal_length'],df['sepal_width'])
axis.set_title("Iris Flower")
axis.set_xlabel('Sepal Width')
axis.set_ylabel('Sepal Length')
# Out:
# Text(0, 0.5, 'Sepal Length')

# %%
# create color dictionary
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}
# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for i in range(len(df['sepal_length'])):
    ax.scatter(df['sepal_length'][i], df['sepal_width'][i],color=colors[df['species'][i]])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %% [markdown]
# 2 types of flowers are not easily seperable, red one is seperable from the other 2

# %%
# create color dictionary
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 'Iris-virginica':'b'}
# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for i in range(len(df['petal_length'])):
    ax.scatter(df['petal_length'][i], df['petal_width'][i],color=colors[df['species'][i]])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('petal_length')
ax.set_ylabel('petal_width')
# Out:
# Text(0, 0.5, 'petal_width')

# %%
# HISTOGRAM
df.plot.hist(subplots=True, layout=(2,2), figsize=(10, 10), bins=20)
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %%
# LINE CHART
# get columns to plot
columns = df.columns.drop(['species'])
# create x data
x_data = range(0, df.shape[0])
# create figure and axis
fig, ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_data, df[column], label=column)
# set title and legend
ax.set_title('Iris Dataset')
ax.legend()

# %%
df= df.sample(frac=1) #shuffles data

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 107           7.3          2.9           6.3          1.8   Iris-virginica
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 55            5.7          2.8           4.5          1.3  Iris-versicolor
# 81            5.5          2.4           3.7          1.0  Iris-versicolor
# 26            5.0          3.4           1.6          0.4      Iris-setosa
# 49            5.0          3.3           1.4          0.2      Iris-setosa
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 48            5.3          3.7           1.5          0.2      Iris-setosa
# 103           6.3          2.9           5.6          1.8   Iris-virginica
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 109           7.2          3.6           6.1          2.5   Iris-virginica
# ...

# %%
features = ['sepal_length','sepal_width']
x=df[features]

# %%
x.describe()
# Out:
#        sepal_length  sepal_width
# count    150.000000   150.000000
# mean       5.843333     3.054000
# std        0.828066     0.433594
# min        4.300000     2.000000
# 25%        5.100000     2.800000
# 50%        5.800000     3.000000
# 75%        6.400000     3.300000
# max        7.900000     4.400000

# %%
pred=df.species
pred
# Out:
# 107     Iris-virginica
# 7          Iris-setosa
# 55     Iris-versicolor
# 81     Iris-versicolor
# 26         Iris-setosa
# 49         Iris-setosa
# 68     Iris-versicolor
# 48         Iris-setosa
# 103     Iris-virginica
# 14         Iris-setosa
# 109     Iris-virginica
# 139     Iris-virginica
# 59     Iris-versicolor
# 44         Iris-setosa
# 116     Iris-virginica
# 3          Iris-setosa
# 128     Iris-virginica
# 115     Iris-virginica
# 90     Iris-versicolor
# 101     Iris-virginica
# 8          Iris-setosa
# 137     Iris-virginica
# 149     Iris-virginica
# 76     Iris-versicolor
# 134     Iris-virginica
# 136     Iris-virginica
# 104     Iris-virginica
# 21         Iris-setosa
# 43         Iris-setosa
# 65     Iris-versicolor
# 51     Iris-versicolor
# 92     Iris-versicolor
# 58     Iris-versicolor
# 23         Iris-setosa
# 63     Iris-versicolor
# 114     Iris-virginica
# 71     Iris-versicolor
# 19         Iris-setosa
# 141     Iris-virginica
# 29         Iris-setosa
# ...

# %%
from sklearn.model_selection import train_test_split
train_x, val_x, train_y, val_y = train_test_split(x, pred, test_size=0.2)

# %%
# 80% in train and 20% in test

# %%
len(train_x)
# Out:
# 120

# %%
len(val_x)
# Out:
# 30

# %%
(train_x.shape, train_y.shape) #120 rows and 2 columns
# Out:
# ((120, 2), (120,))

# %%
from sklearn.tree import DecisionTreeClassifier
deci_tree = DecisionTreeClassifier()
deci_tree.fit(train_x,train_y)
y_val = deci_tree.predict(val_x)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(val_y, y_val))
# Out:
# 0.7333333333333333

# %%
#SVM

# %%
from sklearn.svm import SVC
deci_tree = SVC()
deci_tree.fit(train_x,train_y)
y_val = deci_tree.predict(val_x)

# %%
print(accuracy_score(val_y, y_val))
# Out:
# 0.8

# %%
#Linear Model

# %%
from sklearn.linear_model import LogisticRegression
logi = LogisticRegression()
logi.fit(train_x,train_y)
y_val = logi.predict(val_x)

# %%
print(accuracy_score(val_y, y_val))
# Out:
# 0.8333333333333334
